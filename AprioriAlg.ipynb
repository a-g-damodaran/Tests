# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
og = pd.read_excel(r'C:\Users\Dell\Desktop\DataFolder\OnlineRetail1.xlsx')
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899          CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254         CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138         BAKING SET 9 PIECE RETROSPOT         3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df = og.copy()

# %%
df['Description']= df['Description'].str.strip()

# %%
df.dropna(axis = 0, subset =['InvoiceNo'], inplace = True)

# %%
df['InvoiceNo'] = df['InvoiceNo'].astype('str')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899          CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254         CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138         BAKING SET 9 PIECE RETROSPOT         3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df = df[~df['InvoiceNo'].str.contains('C')]
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899          CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254         CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138         BAKING SET 9 PIECE RETROSPOT         3
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.Description.value_counts()
# Out:
# WHITE HANGING HEART T-LIGHT HOLDER    2327
# JUMBO BAG RED RETROSPOT               2115
# REGENCY CAKESTAND 3 TIER              2019
# PARTY BUNTING                         1707
# LUNCH BAG RED RETROSPOT               1594
#                                       ...
# faulty                                   1
# PINK BOUDOIR T-LIGHT HOLDER              1
# 72 CAKE CASES VINTAGE CHRISTMAS          1
# Found in w/hse                           1
# DOORKNOB CERAMIC IVORY                   1
# Name: Description, Length: 4194, dtype: int64

# %%
bt = df[df['Country']== 'France'].groupby(['InvoiceNo','Description']).sum()
bt
# Out:
#                                            Quantity  UnitPrice  CustomerID
# InvoiceNo Description
# 536370    ALARM CLOCK BAKELIKE GREEN             12       3.75     12583.0
#           ALARM CLOCK BAKELIKE PINK              24       3.75     12583.0
#           ALARM CLOCK BAKELIKE RED               24       3.75     12583.0
#           CHARLOTTE BAG DOLLY GIRL DESIGN        20       0.85     12583.0
#           CIRCUS PARADE LUNCH BOX                24       1.95     12583.0
# ...                                             ...        ...         ...
# 581587    CIRCUS PARADE LUNCH BOX                12       1.95     12680.0
#           PACK OF 20 SPACEBOY NAPKINS            12       0.85     12680.0
#           PLASTERS IN TIN CIRCUS PARADE          12       1.65     12680.0
#           PLASTERS IN TIN STRONGMAN              12       1.65     12680.0
#           SPACEBOY LUNCH BOX                     12       1.95     12680.0
#
# [8372 rows x 3 columns]

# %%
basket = (df[df['Country'] == 'France'].groupby(['InvoiceNo','Description'])['Quantity'].sum().unstack())

# %%
basket
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          NaN                         NaN
# 536852                          NaN                         NaN
# 536974                          NaN                         NaN
# 537065                          NaN                         NaN
# 537463                          NaN                         NaN
# ...                             ...                         ...
# 580986                          NaN                         NaN
# 581001                          NaN                         NaN
# 581171                          NaN                         NaN
# 581279                          NaN                         NaN
# 581587                          NaN                         NaN
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             NaN                              NaN
# ...

# %%
bsk = basket.reset_index().fillna(0).set_index('InvoiceNo')

# %%
bsk
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
# ...                             ...                         ...
# 580986                          0.0                         0.0
# 581001                          0.0                         0.0
# 581171                          0.0                         0.0
# 581279                          0.0                         0.0
# 581587                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# ...

# %%
print(bsk['10 COLOUR SPACEBOY PEN'].value_counts())
# Out:
# 0.0     380
# 24.0     10
# 48.0      2
# Name: 10 COLOUR SPACEBOY PEN, dtype: int64

# %%
(bsk.columns == 'POSTAGE').any()
# Out:
# True

# %%
bsk.POSTAGE
# Out:
# InvoiceNo
# 536370    3.0
# 536852    1.0
# 536974    2.0
# 537065    9.0
# 537463    4.0
#          ...
# 580986    4.0
# 581001    3.0
# 581171    2.0
# 581279    3.0
# 581587    0.0
# Name: POSTAGE, Length: 392, dtype: float64

# %%
def encode_units(x):
    if x <= 0:
        return 0
    elif x >= 1:
        return 1
bsk_sets = bsk.applymap(encode_units)
bsk_sets.drop('POSTAGE', inplace = True, axis = 1)
bsk_sets
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                            0                           0
# 536852                            0                           0
# 536974                            0                           0
# 537065                            0                           0
# 537463                            0                           0
# ...                             ...                         ...
# 580986                            0                           0
# 581001                            0                           0
# 581171                            0                           0
# 581279                            0                           0
# 581587                            0                           0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                               0                                0
# ...

# %%
print(bsk_sets['10 COLOUR SPACEBOY PEN'].value_counts())
# Out:
# 0    380
# 1     12
# Name: 10 COLOUR SPACEBOY PEN, dtype: int64

# %%
frequent_itemsets = apriori(bsk_sets,  min_support=0.07,use_colnames=True),

# %%
type(frequent_itemsets)
# Out:
# tuple

# %%
len(frequent_itemsets)
# Out:
# 1

# %%
frequent_itemsets[0]
# Out:
#      support                                           itemsets
# 0   0.071429                      (4 TRADITIONAL SPINNING TOPS)
# 1   0.096939                       (ALARM CLOCK BAKELIKE GREEN)
# 2   0.102041                        (ALARM CLOCK BAKELIKE PINK)
# 3   0.094388                         (ALARM CLOCK BAKELIKE RED)
# 4   0.081633                     (BAKING SET 9 PIECE RETROSPOT)
# 5   0.071429                     (CHILDRENS CUTLERY DOLLY GIRL)
# 6   0.099490                             (DOLLY GIRL LUNCH BOX)
# 7   0.096939                          (JUMBO BAG RED RETROSPOT)
# 8   0.076531                       (JUMBO BAG WOODLAND ANIMALS)
# 9   0.125000                           (LUNCH BAG APPLE DESIGN)
# 10  0.084184                      (LUNCH BAG DOLLY GIRL DESIGN)
# 11  0.153061                          (LUNCH BAG RED RETROSPOT)
# 12  0.119898                        (LUNCH BAG SPACEBOY DESIGN)
# 13  0.117347                               (LUNCH BAG WOODLAND)
# ...

# %%
rules = association_rules(frequent_itemsets[0], metric='lift', min_threshold = 1)

# %%
rules
# Out:
#                                           antecedents  \
# 0                        (ALARM CLOCK BAKELIKE GREEN)
# 1                         (ALARM CLOCK BAKELIKE PINK)
# 2                        (ALARM CLOCK BAKELIKE GREEN)
# 3                          (ALARM CLOCK BAKELIKE RED)
# 4                         (ALARM CLOCK BAKELIKE PINK)
# 5                          (ALARM CLOCK BAKELIKE RED)
# 6                                (SPACEBOY LUNCH BOX)
# 7                              (DOLLY GIRL LUNCH BOX)
# 8                     (PLASTERS IN TIN CIRCUS PARADE)
# 9                          (PLASTERS IN TIN SPACEBOY)
# 10                    (PLASTERS IN TIN CIRCUS PARADE)
# 11                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 12                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 13                         (PLASTERS IN TIN SPACEBOY)
# 14               (SET/20 RED RETROSPOT PAPER NAPKINS)
# 15                      (SET/6 RED SPOTTY PAPER CUPS)
# ...

# %%
rules[(rules['lift']>=6)&(rules['confidence']>=0.8)]
# Out:
#                                           antecedents  \
# 2                        (ALARM CLOCK BAKELIKE GREEN)
# 3                          (ALARM CLOCK BAKELIKE RED)
# 17                    (SET/6 RED SPOTTY PAPER PLATES)
# 18                    (SET/6 RED SPOTTY PAPER PLATES)
# 19                      (SET/6 RED SPOTTY PAPER CUPS)
# 20  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 21  (SET/20 RED RETROSPOT PAPER NAPKINS, SET/6 RED...
# 22  (SET/6 RED SPOTTY PAPER PLATES, SET/6 RED SPOT...
#
#                              consequents  antecedent support  \
# 2             (ALARM CLOCK BAKELIKE RED)            0.096939
# 3           (ALARM CLOCK BAKELIKE GREEN)            0.094388
# 17  (SET/20 RED RETROSPOT PAPER NAPKINS)            0.127551
# 18         (SET/6 RED SPOTTY PAPER CUPS)            0.127551
# 19       (SET/6 RED SPOTTY PAPER PLATES)            0.137755
# 20         (SET/6 RED SPOTTY PAPER CUPS)            0.102041
# ...

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules

# %%
pdf1 = pd.read_excel(r'C:\Users\Dell\Desktop\DataFolder\OnlineRetail1.xlsx')

# %%
pdf1 = og.copy()

# %%
pdf1.dropna(axis = 0, subset = ['InvoiceNo'], inplace = True)

# %%
pdf1['InvoiceNo'] = pdf1['InvoiceNo'].astype('str')
pdf1['Description']= pdf1['Description'].str.strip()
pdf1 = pdf1[~pdf1['InvoiceNo'].str.contains('C')]

# %%
pdf1 = pdf1[pdf1['Country']=='France']

# %%
pdf1
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727         ALARM CLOCK BAKELIKE RED        24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                  STARS GIFT TAPE        24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899      CHILDREN'S APRON DOLLY GIRL         6
# 541906    581587     23254     CHILDRENS CUTLERY DOLLY GIRL         4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138     BAKING SET 9 PIECE RETROSPOT         3
#
#                 InvoiceDate  UnitPrice  CustomerID Country
# 26      2010-01-12 08:45:00       3.75     12583.0  France
# ...

# %%
pdf1 = pdf1.groupby(['InvoiceNo','Description']).Quantity.sum()

# %%
pdf1 = pdf1.unstack()

# %%
pdf1 = pdf1.fillna(0)

# %%
pdf1
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                          0.0                         0.0
# 536852                          0.0                         0.0
# 536974                          0.0                         0.0
# 537065                          0.0                         0.0
# 537463                          0.0                         0.0
# ...                             ...                         ...
# 580986                          0.0                         0.0
# 581001                          0.0                         0.0
# 581171                          0.0                         0.0
# 581279                          0.0                         0.0
# 581587                          0.0                         0.0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                             0.0                              0.0
# ...

# %%
def encod1(x):
    if x <= 0:
        return 0
    elif x >=1:
        return 1

# %%
bsk1 = pdf1.applymap(encod1)

# %%
bsk1.drop('POSTAGE', axis = 1, inplace = True)

# %%
bsk1
# Out:
# Description  10 COLOUR SPACEBOY PEN  12 COLOURED PARTY BALLOONS  \
# InvoiceNo
# 536370                            0                           0
# 536852                            0                           0
# 536974                            0                           0
# 537065                            0                           0
# 537463                            0                           0
# ...                             ...                         ...
# 580986                            0                           0
# 581001                            0                           0
# 581171                            0                           0
# 581279                            0                           0
# 581587                            0                           0
#
# Description  12 EGG HOUSE PAINTED WOOD  12 MESSAGE CARDS WITH ENVELOPES  \
# InvoiceNo
# 536370                               0                                0
# ...

# %%
frq1 = apriori(bsk1,min_support=0.1,use_colnames=True,max_len=None,verbose=0,low_memory=False,)

# %%
frq1
# Out:
#      support                                           itemsets
# 0   0.102041                        (ALARM CLOCK BAKELIKE PINK)
# 1   0.125000                           (LUNCH BAG APPLE DESIGN)
# 2   0.153061                          (LUNCH BAG RED RETROSPOT)
# 3   0.119898                        (LUNCH BAG SPACEBOY DESIGN)
# 4   0.117347                               (LUNCH BAG WOODLAND)
# 5   0.142857                 (LUNCH BOX WITH CUTLERY RETROSPOT)
# 6   0.104592                           (MINI PAINT SET VINTAGE)
# 7   0.102041                  (PACK OF 72 RETROSPOT CAKE CASES)
# 8   0.168367                    (PLASTERS IN TIN CIRCUS PARADE)
# 9   0.137755                         (PLASTERS IN TIN SPACEBOY)
# 10  0.170918                 (PLASTERS IN TIN WOODLAND ANIMALS)
# 11  0.188776                               (RABBIT NIGHT LIGHT)
# 12  0.137755                         (RED RETROSPOT MINI CASES)
# 13  0.181122                    (RED TOADSTOOL LED NIGHT LIGHT)
# ...

# %%
frq2 = association_rules(frq1, metric='lift', min_threshold=1,support_only=False,)

# %%
frq2
# Out:
#                             antecedents                           consequents  \
# 0       (PLASTERS IN TIN CIRCUS PARADE)    (PLASTERS IN TIN WOODLAND ANIMALS)
# 1    (PLASTERS IN TIN WOODLAND ANIMALS)       (PLASTERS IN TIN CIRCUS PARADE)
# 2    (PLASTERS IN TIN WOODLAND ANIMALS)            (PLASTERS IN TIN SPACEBOY)
# 3            (PLASTERS IN TIN SPACEBOY)    (PLASTERS IN TIN WOODLAND ANIMALS)
# 4  (SET/20 RED RETROSPOT PAPER NAPKINS)         (SET/6 RED SPOTTY PAPER CUPS)
# 5         (SET/6 RED SPOTTY PAPER CUPS)  (SET/20 RED RETROSPOT PAPER NAPKINS)
# 6  (SET/20 RED RETROSPOT PAPER NAPKINS)       (SET/6 RED SPOTTY PAPER PLATES)
# 7       (SET/6 RED SPOTTY PAPER PLATES)  (SET/20 RED RETROSPOT PAPER NAPKINS)
# 8       (SET/6 RED SPOTTY PAPER PLATES)         (SET/6 RED SPOTTY PAPER CUPS)
# 9         (SET/6 RED SPOTTY PAPER CUPS)       (SET/6 RED SPOTTY PAPER PLATES)
#
#    antecedent support  consequent support   support  confidence      lift  \
# ...

# %%
frq3 = association_rules(frq1, metric='confidence', min_threshold=0.7,support_only=False,)

# %%
frq3
# Out:
#                             antecedents                           consequents  \
# 0            (PLASTERS IN TIN SPACEBOY)    (PLASTERS IN TIN WOODLAND ANIMALS)
# 1  (SET/20 RED RETROSPOT PAPER NAPKINS)         (SET/6 RED SPOTTY PAPER CUPS)
# 2         (SET/6 RED SPOTTY PAPER CUPS)  (SET/20 RED RETROSPOT PAPER NAPKINS)
# 3  (SET/20 RED RETROSPOT PAPER NAPKINS)       (SET/6 RED SPOTTY PAPER PLATES)
# 4       (SET/6 RED SPOTTY PAPER PLATES)  (SET/20 RED RETROSPOT PAPER NAPKINS)
# 5       (SET/6 RED SPOTTY PAPER PLATES)         (SET/6 RED SPOTTY PAPER CUPS)
# 6         (SET/6 RED SPOTTY PAPER CUPS)       (SET/6 RED SPOTTY PAPER PLATES)
#
#    antecedent support  consequent support   support  confidence      lift  \
# 0            0.137755            0.170918  0.104592    0.759259  4.442233
# 1            0.132653            0.137755  0.102041    0.769231  5.584046
# 2            0.137755            0.132653  0.102041    0.740741  5.584046
# ...
